# %%
import planck_physics
# Out:
# /Users/egentry/anaconda/lib/python3.4/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %% [markdown]
# # Get integration results

# %%
from integrator import integrator

T = 300 # [K]
nu_0 = 1e10
nu_1 = 1e15
B_integrated = integrator(planck_physics.B_nu, nu_0, nu_1, T )
B_analytic   = planck_physics.B(T)

print("B_integrated: ", B_integrated)
print("B_analytic:   ", B_analytic)
# Out:
# B_integrated:  146199.787683
# B_analytic:    146199.79852422082

# %% [markdown]
# # Get root finder results

# %%
from root_finder import root_finder

# %% [markdown]
# ## Peaks of $B_\nu$ and $B_\lambda$

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns; sns.set(context="poster")
import numpy as np

plt.figure()
xs = np.linspace(0,10)
plt.plot(xs, planck_physics.d_B_nu_d_nu_dimensionless(xs))
plt.axhline(y=0, linestyle="dashed")
plt.xlabel(r"$x$")
plt.ylabel(r"$dB / dx$ [arbitrary units]")

plt.figure()
ys = np.linspace(0,10)
plt.plot(ys, planck_physics.d_B_lambda_d_lambda_dimensionless(ys))
plt.axhline(y=0, linestyle="dashed")
plt.xlabel(r"$y$")
plt.ylabel(r"$dB / dy$ [arbitrary units]")

# %%
from IPython.display import display, Math

x_0 = 3
Wein_peak_nu_dimensionless = root_finder(planck_physics.d_B_nu_d_nu_dimensionless, x_0)
display(Math(r"B_\nu \text{{ peaks at: }} x = {0:.4} \frac{{h \nu}}{{k T}}".format(Wein_peak_nu_dimensionless)) )


y_0 = 5
Wein_peak_lambda_dimensionless = root_finder(planck_physics.d_B_lambda_d_lambda_dimensionless, y_0)
display(Math(r"B_\lambda \text{{ peaks at: }} y = {0:.4} \frac{{h c}}{{\lambda k T}}".format(Wein_peak_lambda_dimensionless)) )
# Out:
# $$B_\nu \text{ peaks at: } x = 2.822 \frac{h \nu}{k T}$$
# $$B_\lambda \text{ peaks at: } y = 4.965 \frac{h c}{\lambda k T}$$

# %% [markdown]
# ## Peak of $\frac{\partial B_\nu}{\partial T}$

# %%
xs = np.linspace(0,10)
plt.plot(xs, planck_physics.d_B_nu_d_T_d_nu_dimensionless(xs))
plt.axhline(y=0, linestyle="dashed")
plt.xlabel(r"$x$")
plt.ylabel(r"$\frac{\partial^2B}{\partial x \partial T}$ [arbitrary units]")

# %%
x_0 = 4
d_B_nu_dT_peak_dimensionless = root_finder(planck_physics.d_B_nu_d_T_d_nu_dimensionless, x_0)
display(Math(r"\frac{{\partial B_\nu}}{{\partial T}} \text{{ peaks at: }} x = {0:.4} \frac{{h \nu}}{{k T}}".format(d_B_nu_dT_peak_dimensionless)) )
# Out:
# $$\frac{\partial B_\nu}{\partial T} \text{ peaks at: } x = 3.83 \frac{h \nu}{k T}$$
